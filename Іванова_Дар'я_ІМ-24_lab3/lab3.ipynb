# %%
#  🧠🧠🧠 Готова лабораторна номер 3 🧠🧠🧠


# === ІМПОРТИ ТА ІНІЦІАЛІЗАЦІЯ ===
import os, random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from collections import deque






# 🧩🧩🧩🧩 РОБОТА З ГРАФОМ 🧩🧩🧩🧩


def generate_graph(width, height):
    """Створення сіткового графа з обмеженнями швидкості."""
    G = nx.Graph()
    speed_limits = {}

    for i in range(width):
        for j in range(height):
            G.add_node((i, j))  # Додавання вузла на координати (i, j)

            # Додавання ребра ліворуч (якщо не на першому стовпчику)
            if i > 0:
                G.add_edge((i, j), (i - 1, j))
                speed_limits[((i, j), (i - 1, j))] = random.choice(range(20, 100, 10))  # Призначення випадкової швидкості

            # Додавання ребра згори (якщо не в першому рядку)
            if j > 0:
                G.add_edge((i, j), (i, j - 1))
                speed_limits[((i, j), (i, j - 1))] = random.choice(range(20, 100, 10))  # Призначення випадкової швидкості

    return G, speed_limits  # Повернення графа та словника швидкостей





def remove_random_edges(G, remove_count):
    """Видалення випадкових ребер із перевіркою на зв'язність."""
    edges = list(G.edges())  # Отримання списку всіх ребер
    max_removable_edges = len(edges)

    # Обмеження кількості видаляємих ребер, якщо задане число перевищує доступне
    if remove_count > max_removable_edges:
        remove_count = max_removable_edges

    # Випадковий вибір ребер для видалення
    removed_edges = random.sample(edges, remove_count)
    
    for edge in removed_edges:
        G.remove_edge(*edge)  # Видалення ребра

        # Перевірка на збереження зв'язності
        if not nx.is_connected(G):
            G.add_edge(*edge)  # Відновлення ребра, якщо граф розірвався
            
    return G  # Повернення оновленого графа


    



# 👀👀👀👀 База знань агента 👀👀👀👀

class KnowledgeBase:
    """База знань агента для зберігання інформації про граф-дорогу."""

    def __init__(self):
        self.visited_nodes = set()       # Вузли, які агент уже відвідав
        self.known_edges = set()         # Відомі дороги (ребра) між вузлами
        self.road_signs = {}             # Дорожні знаки для напрямків (звідки → куди)

    def tell_visited(self, node):
        """Додавання відвіданого вузла."""
        self.visited_nodes.add(node)
        print(f"TELL: Вузол {node} додано до відвіданих.")

    def tell_edge(self, node1, node2):
        """Додавання відомого ребра (дороги)."""
        self.known_edges.add((node1, node2))
        self.known_edges.add((node2, node1))  # Обидва напрямки
        print(f"TELL: Дорога {node1} <-> {node2} додана в базу знань.")

    def tell_sign(self, from_node, to_node, sign_info):
        """Збереження дорожнього знака для напрямку."""
        if from_node not in self.road_signs:
            self.road_signs[from_node] = {}
        self.road_signs[from_node][to_node] = sign_info
        print(f"TELL: Дорожній знак {from_node} -> {to_node}: {sign_info} додано.")

    def ask_visited(self, node):
        """Перевірка, чи вузол уже відвідано."""
        return node in self.visited_nodes

    def ask_possible_moves(self, node):
        """Отримання доступних напрямків руху з вузла."""
        return self.road_signs.get(node, {})

    def ask_known_edges(self):
        """Отримання всіх відомих доріг."""
        return self.known_edges


# Ініціалізація бази знань
kb = KnowledgeBase()
print("\n--- База знань агента ---")
print(f"Відвідані вузли: {kb.visited_nodes}")
print(f"Відомі дороги: {kb.known_edges}")
print(f"Дорожні знаки: {kb.road_signs}")
print("--------------------------\n")


    
# 👁👁👁👁 Візуалізація руху 👁👁👁👁


def draw_graph(G, agent_pos, visited, path, seen, start, end, previous_pos=None, edge_speeds=None):
    """Візуалізація графа з кольоровим виділенням вузлів."""

    # Побудова позицій вузлів для графіка
    pos = {(x, y): (x, -y) for x, y in G.nodes()}

    node_colors = []
    for node in G.nodes():
        if node == agent_pos:
            node_colors.append("red")  # Поточна позиція агента
        elif node == end:
            node_colors.append("green")  # Кінцева точка
        elif node in path:
            node_colors.append("lightgreen")  # Пройдений шлях
        elif node in seen:
            node_colors.append("yellow")  # Переглянуті, але не відвідані
        elif node not in visited:
            node_colors.append("blue")  # Не відвідані і не переглянуті
        else:
            node_colors.append("white")  # Відвідані

    plt.figure(figsize=(8, 8))
    nx.draw(G, pos, with_labels=True, node_size=400, node_color=node_colors, edge_color="black")

    # Додавання текстових підписів на ребрах (наприклад, швидкість, якщо edge_speeds передано)
    if edge_speeds:
        edge_labels = {(min(edge), max(edge)): f"{speed} км/год" for edge, speed in edge_speeds.items()}
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

    plt.title(f"Агент знаходиться у {agent_pos}")
    plt.show()






# 🕹🕹🕹🕹 Логіка руху агента 🕹🕹🕹🕹



def move_agent_with_knowledge(G, kb, start, end, max_steps=50):
    """Функція для руху агента з використанням бази знань."""

    # Ініціалізація змінних
    visited = set()
    path = []
    seen = deque()
    avoid_nodes = set()
    current_pos = start
    previous_pos = None
    direction = "right"
    step_count = 0
    in_dead_end = False
    visited_nodes_counter = {}
    skip_speed_check = False  # залишено на випадок логіки тупиків
    while current_pos != end and step_count < max_steps:
        visited.add(current_pos)
        path.append(current_pos)
        kb.tell_visited(current_pos)
        step_count += 1
    
        print(f"\n🚗 Крок {step_count}: Агент рухається до {current_pos}")

        neighbors = list(G.neighbors(current_pos))
        print(f"🔍 Сканування сусідніх перехресть для вузла {current_pos}: {neighbors}")

        for neighbor in neighbors:
            kb.tell_edge(current_pos, neighbor)
            direction_sign = get_direction(current_pos, neighbor)
            kb.tell_sign(current_pos, neighbor, direction_sign)
            print(f"🚸 Дорожній знак: з {current_pos} у {neighbor} -> {direction_sign}")

            if len(list(G.neighbors(neighbor))) == 1 and neighbor != end:
                avoid_nodes.add(neighbor)
                print(f"⚠ Виявлено тупиковий вузол: {neighbor}, він буде уникатись.")

            if neighbor not in visited and neighbor not in seen:
                seen.append(neighbor)
                print(f"👀 Додано до бачених вузлів: {neighbor}")

        if current_pos in seen:
            seen.remove(current_pos)

        print(f"🧭 Поточний напрямок: {direction}")

        # Виявлення циклів
        visited_nodes_counter[current_pos] = visited_nodes_counter.get(current_pos, 0) + 1
        if visited_nodes_counter[current_pos] > 2:
            in_dead_end = True
            print(f"🔄 ЦИКЛ ВИЯВЛЕНО! ВХІД У СТАН ТУПИКА на вузлі {current_pos}")

        # Тупики: рух до жовтих точок
        if (len(neighbors) == 1 and previous_pos in neighbors) or in_dead_end:
            in_dead_end = True
            if seen:
                target_seen = next((node for node in reversed(seen) if node not in avoid_nodes), None)
                print(f"↩ ТУПИК! Агент прямує покроково до жовтої точки {target_seen}")

                if target_seen:
                    try:
                        shortest_path = nx.shortest_path(G, current_pos, target_seen)
                        next_pos = shortest_path[1]
                        new_direction = get_direction(current_pos, next_pos)
                        direction = new_direction
                        previous_pos = current_pos
                        current_pos = next_pos

                        draw_graph(G, current_pos, visited, path, seen, start, end, previous_pos, None)
                        continue
                    except nx.NetworkXNoPath:
                        print("❌ Немає шляху до жовтої точки, завершення руху.")
                        break
                else:
                    print("❌ Немає жовтих точок для повернення, завершення руху.")
                    break
        else:
            new_moves, old_moves = analyze_moves(G, current_pos, visited)
            possible_moves = [node for node in new_moves + old_moves if node not in avoid_nodes]

            if not possible_moves:
                print("🚫 Немає допустимих рухів, завершення руху.")
                break

            if end in seen:
                print(f"🎯 Кінцева точка {end} була переглянута, рухаємося покроково!")
                shortest_path = nx.shortest_path(G, current_pos, end)
                next_pos = shortest_path[1]
            else:
                next_pos = min(possible_moves, key=lambda pos: abs(pos[0] - end[0]) + abs(pos[1] - end[1]))

        new_direction = get_direction(current_pos, next_pos)
        if new_direction != direction:
            if (direction, new_direction) in [("up", "right"), ("right", "down"), ("down", "left"), ("left", "up")]:
                print("➡ Поворот направо")
            elif (direction, new_direction) in [("up", "left"), ("left", "down"), ("down", "right"), ("right", "up")]:
                print("⬅ Поворот наліво")
            else:
                print("🔄 Розворот на 180 градусів")

        draw_graph(G, current_pos, visited, path, seen, start, end, previous_pos, None)

        direction = new_direction
        previous_pos = current_pos
        current_pos = next_pos

    if current_pos == end:
        kb.tell_visited(current_pos)
        path.append(current_pos)
        visited.add(current_pos)
        print(f"🏁 Досягнуто кінцевої точки! Додана {current_pos} до visited_nodes.")
        draw_graph(G, current_pos, visited, path, seen, start, end, previous_pos, None)

    print("✅ Рух завершено!")
    print(f"📊 Фактична кількість кроків агента: {step_count}")

    return visited, path, seen, step_count










    
# 🧩🧩🧩🧩 Допоміжні функції 🧩🧩🧩🧩


def get_direction(from_pos, to_pos):
    """Визначення напрямку руху агента."""
    dx, dy = to_pos[0] - from_pos[0], to_pos[1] - from_pos[1]
    if dx == 1: return "right"
    if dx == -1: return "left"
    if dy == -1: return "up"
    if dy == 1: return "down"
    return None


def analyze_moves(G, current_pos, visited):
    """Аналіз можливих рухів агента."""
    neighbors = list(G.neighbors(current_pos))
    new_moves = [node for node in neighbors if node not in visited]
    old_moves = [node for node in neighbors if node in visited]
    return new_moves, old_moves


def print_knowledge_base(kb):
    """Вивід поточного стану бази знань агента."""
    print("\n--- База знань агента ---")
    print(f"Відвідані вузли: {kb.visited_nodes}")
    print(f"Відомі дороги: {kb.known_edges}")
    print(f"Дорожні знаки:")
    for node, signs in kb.road_signs.items():
        print(f"  {node}: {signs}")
    print("--------------------------\n")
    

def _update_agent_state(current_pos, visited, path, kb):
    """Оновлення стану агента (додавання у базу знань)."""
    visited.add(current_pos)
    path.append(current_pos)
    kb.tell_visited(current_pos)


def _analyze_neighbors(G, current_pos, kb, seen, avoid_nodes, visited):
    """Аналіз сусідніх вузлів, додавання інформації до бази знань."""
    neighbors = list(G.neighbors(current_pos))
    for neighbor in neighbors:
        kb.tell_edge(current_pos, neighbor)
        direction_sign = get_direction(current_pos, neighbor)
        kb.tell_sign(current_pos, neighbor, direction_sign)

        # Перевірка сусідніх вузлів на тупики та унікальність
        neighbor_neighbors = list(G.neighbors(neighbor))
        if len(neighbor_neighbors) == 1:
            avoid_nodes.add(neighbor)

        # Додаєвання вузлів в список бачених, якщо вони ще не відвідані
        if neighbor not in visited and neighbor not in seen:
            seen.append(neighbor)

        # Аналіз сусідніх перехресть та збереження їхньої структури
        for neighbor_of_neighbor in G.neighbors(neighbor):
            if neighbor_of_neighbor != current_pos and neighbor_of_neighbor not in visited:
                kb.tell_sign(neighbor, neighbor_of_neighbor, get_direction(neighbor, neighbor_of_neighbor))
                seen.append(neighbor_of_neighbor)

    # Видалення відвіданих вузли зі списку бачених
    seen = deque([node for node in seen if node not in visited])




def _print_status(step_count, current_pos, direction):
    """Вивід поточного статусу агента."""
    print(f"\nКрок {step_count}: Агент рухається до {current_pos}")
    print(f"Поточний напрямок: {direction}")



def _handle_decision(G, kb, current_pos, end, seen, avoid_nodes, visited, path, in_dead_end):
    """Обробка досягнення кінцевої точки або рух до бачених точок."""
    new_moves, old_moves = analyze_moves(G, current_pos, visited)
    possible_moves = [node for node in new_moves + old_moves if node not in avoid_nodes]

    # Якщо кінцева точка є серед бачених вузлів, рух до неї покроковий
    if end in seen:
        print(f"Кінцева точка {end} була переглянута, рухаємося покроково!")
        shortest_path = nx.shortest_path(G, current_pos, end)
        return shortest_path[1], False  # Повертання наступного кроку у шляху

    if not possible_moves or in_dead_end:
        return _handle_dead_end(G, current_pos, seen, avoid_nodes, in_dead_end)

    return min(possible_moves, key=lambda pos: abs(pos[0] - end[0]) + abs(pos[1] - end[1])), False




def _update_direction(direction, current_pos, next_pos):
    """Оновлення напрямку руху агента."""
    new_direction = get_direction(current_pos, next_pos)
    if new_direction != direction:
        if (direction, new_direction) in [("up", "right"), ("right", "down"), ("down", "left"), ("left", "up")]:
            print("Поворот направо")
        elif (direction, new_direction) in [("up", "left"), ("left", "down"), ("down", "right"), ("right", "up")]:
            print("Поворот наліво")
        else:
            print("Розворот на 180 градусів")
    return new_direction


def _finalize_run(current_pos, end, kb, path, visited, step_count):
    """Остаточне оновлення при досягненні цілі або завершенні за кількістю кроків."""
    if current_pos == end:
        kb.tell_visited(current_pos)
        path.append(current_pos)
        visited.add(current_pos)
        print(f"🏁 Досягнуто кінцевої точки! Додаю {current_pos} до visited_nodes.")

    print("✅ Рух завершено!")
    print(f"📊 Фактична кількість кроків агента: {step_count}")





# 🚀🚀🚀🚀 Запуск та тестування 🚀🚀🚀🚀

def test_agent_behavior():
    """Тестування роботи агента з графом без зображень."""
    test_graph_width, test_graph_height = 5, 5
    test_start, test_end = (0, 0), (4, 4)

    G = nx.grid_2d_graph(test_graph_width, test_graph_height)
    G = remove_random_edges(G, remove_count=25)

    kb = KnowledgeBase()

    assert nx.has_path(G, test_start, test_end), "Граф розірваний, немає шляху між стартом і фінішем!"

    visited_nodes, path_taken, seen_nodes, total_steps = move_agent_with_knowledge(G, kb, test_start, test_end, max_steps=100)

    print(f"Шлях агента: {path_taken}")
    print(f"Фінальна позиція: {path_taken[-1]}")

    assert test_end in visited_nodes, "Агент не досягнув цільової точки!"
    assert total_steps > 0, "Агент не зробив жодного кроку!"
    assert len(visited_nodes) > 0, "Жоден вузол не був відвіданий!"

    print("✅ Усі тести пройдені успішно!")


# Виконання тестів


    
test_agent_behavior()
# Out:
# --- База знань агента ---
# Відвідані вузли: set()
# Відомі дороги: set()
# Дорожні знаки: {}
# --------------------------
#
# TELL: Вузол (0, 0) додано до відвіданих.
#
# 🚗 Крок 1: Агент рухається до (0, 0)
# 🔍 Сканування сусідніх перехресть для вузла (0, 0): [(1, 0), (0, 1)]
# TELL: Дорога (0, 0) <-> (1, 0) додана в базу знань.
# TELL: Дорожній знак (0, 0) -> (1, 0): right додано.
# 🚸 Дорожній знак: з (0, 0) у (1, 0) -> right
# 👀 Додано до бачених вузлів: (1, 0)
# TELL: Дорога (0, 0) <-> (0, 1) додана в базу знань.
# TELL: Дорожній знак (0, 0) -> (0, 1): down додано.
# 🚸 Дорожній знак: з (0, 0) у (0, 1) -> down
# 👀 Додано до бачених вузлів: (0, 1)
# 🧭 Поточний напрямок: right
# TELL: Вузол (1, 0) додано до відвіданих.
#
# 🚗 Крок 2: Агент рухається до (1, 0)
# 🔍 Сканування сусідніх перехресть для вузла (1, 0): [(2, 0), (0, 0)]
# TELL: Дорога (1, 0) <-> (2, 0) додана в базу знань.
# TELL: Дорожній знак (1, 0) -> (2, 0): right додано.
# 🚸 Дорожній знак: з (1, 0) у (2, 0) -> right
# 👀 Додано до бачених вузлів: (2, 0)
# TELL: Дорога (1, 0) <-> (0, 0) додана в базу знань.
# TELL: Дорожній знак (1, 0) -> (0, 0): left додано.
# 🚸 Дорожній знак: з (1, 0) у (0, 0) -> left
# 🧭 Поточний напрямок: right
# TELL: Вузол (2, 0) додано до відвіданих.
#
# 🚗 Крок 3: Агент рухається до (2, 0)
# 🔍 Сканування сусідніх перехресть для вузла (2, 0): [(1, 0), (3, 0), (2, 1)]
# TELL: Дорога (2, 0) <-> (1, 0) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (1, 0): left додано.
# 🚸 Дорожній знак: з (2, 0) у (1, 0) -> left
# TELL: Дорога (2, 0) <-> (3, 0) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (3, 0): right додано.
# 🚸 Дорожній знак: з (2, 0) у (3, 0) -> right
# 👀 Додано до бачених вузлів: (3, 0)
# TELL: Дорога (2, 0) <-> (2, 1) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (2, 1): down додано.
# 🚸 Дорожній знак: з (2, 0) у (2, 1) -> down
# ⚠ Виявлено тупиковий вузол: (2, 1), він буде уникатись.
# 👀 Додано до бачених вузлів: (2, 1)
# 🧭 Поточний напрямок: right
# TELL: Вузол (3, 0) додано до відвіданих.
#
# 🚗 Крок 4: Агент рухається до (3, 0)
# 🔍 Сканування сусідніх перехресть для вузла (3, 0): [(2, 0), (4, 0)]
# TELL: Дорога (3, 0) <-> (2, 0) додана в базу знань.
# TELL: Дорожній знак (3, 0) -> (2, 0): left додано.
# 🚸 Дорожній знак: з (3, 0) у (2, 0) -> left
# TELL: Дорога (3, 0) <-> (4, 0) додана в базу знань.
# TELL: Дорожній знак (3, 0) -> (4, 0): right додано.
# 🚸 Дорожній знак: з (3, 0) у (4, 0) -> right
# ⚠ Виявлено тупиковий вузол: (4, 0), він буде уникатись.
# 👀 Додано до бачених вузлів: (4, 0)
# 🧭 Поточний напрямок: right
# 🔄 Розворот на 180 градусів
# TELL: Вузол (2, 0) додано до відвіданих.
#
# 🚗 Крок 5: Агент рухається до (2, 0)
# 🔍 Сканування сусідніх перехресть для вузла (2, 0): [(1, 0), (3, 0), (2, 1)]
# TELL: Дорога (2, 0) <-> (1, 0) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (1, 0): left додано.
# 🚸 Дорожній знак: з (2, 0) у (1, 0) -> left
# TELL: Дорога (2, 0) <-> (3, 0) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (3, 0): right додано.
# 🚸 Дорожній знак: з (2, 0) у (3, 0) -> right
# TELL: Дорога (2, 0) <-> (2, 1) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (2, 1): down додано.
# 🚸 Дорожній знак: з (2, 0) у (2, 1) -> down
# ⚠ Виявлено тупиковий вузол: (2, 1), він буде уникатись.
# 🧭 Поточний напрямок: left
# 🔄 Розворот на 180 градусів
# TELL: Вузол (3, 0) додано до відвіданих.
#
# 🚗 Крок 6: Агент рухається до (3, 0)
# 🔍 Сканування сусідніх перехресть для вузла (3, 0): [(2, 0), (4, 0)]
# TELL: Дорога (3, 0) <-> (2, 0) додана в базу знань.
# TELL: Дорожній знак (3, 0) -> (2, 0): left додано.
# 🚸 Дорожній знак: з (3, 0) у (2, 0) -> left
# TELL: Дорога (3, 0) <-> (4, 0) додана в базу знань.
# TELL: Дорожній знак (3, 0) -> (4, 0): right додано.
# 🚸 Дорожній знак: з (3, 0) у (4, 0) -> right
# ⚠ Виявлено тупиковий вузол: (4, 0), він буде уникатись.
# 🧭 Поточний напрямок: right
# 🔄 Розворот на 180 градусів
# TELL: Вузол (2, 0) додано до відвіданих.
#
# 🚗 Крок 7: Агент рухається до (2, 0)
# 🔍 Сканування сусідніх перехресть для вузла (2, 0): [(1, 0), (3, 0), (2, 1)]
# TELL: Дорога (2, 0) <-> (1, 0) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (1, 0): left додано.
# 🚸 Дорожній знак: з (2, 0) у (1, 0) -> left
# TELL: Дорога (2, 0) <-> (3, 0) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (3, 0): right додано.
# 🚸 Дорожній знак: з (2, 0) у (3, 0) -> right
# TELL: Дорога (2, 0) <-> (2, 1) додана в базу знань.
# TELL: Дорожній знак (2, 0) -> (2, 1): down додано.
# 🚸 Дорожній знак: з (2, 0) у (2, 1) -> down
# ⚠ Виявлено тупиковий вузол: (2, 1), він буде уникатись.
# 🧭 Поточний напрямок: left
# 🔄 ЦИКЛ ВИЯВЛЕНО! ВХІД У СТАН ТУПИКА на вузлі (2, 0)
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (0, 1)
# TELL: Вузол (1, 0) додано до відвіданих.
#
# 🚗 Крок 8: Агент рухається до (1, 0)
# 🔍 Сканування сусідніх перехресть для вузла (1, 0): [(2, 0), (0, 0)]
# TELL: Дорога (1, 0) <-> (2, 0) додана в базу знань.
# TELL: Дорожній знак (1, 0) -> (2, 0): right додано.
# 🚸 Дорожній знак: з (1, 0) у (2, 0) -> right
# TELL: Дорога (1, 0) <-> (0, 0) додана в базу знань.
# TELL: Дорожній знак (1, 0) -> (0, 0): left додано.
# 🚸 Дорожній знак: з (1, 0) у (0, 0) -> left
# 🧭 Поточний напрямок: left
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (0, 1)
# TELL: Вузол (0, 0) додано до відвіданих.
#
# 🚗 Крок 9: Агент рухається до (0, 0)
# 🔍 Сканування сусідніх перехресть для вузла (0, 0): [(1, 0), (0, 1)]
# TELL: Дорога (0, 0) <-> (1, 0) додана в базу знань.
# TELL: Дорожній знак (0, 0) -> (1, 0): right додано.
# 🚸 Дорожній знак: з (0, 0) у (1, 0) -> right
# TELL: Дорога (0, 0) <-> (0, 1) додана в базу знань.
# TELL: Дорожній знак (0, 0) -> (0, 1): down додано.
# 🚸 Дорожній знак: з (0, 0) у (0, 1) -> down
# 🧭 Поточний напрямок: left
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (0, 1)
# TELL: Вузол (0, 1) додано до відвіданих.
#
# 🚗 Крок 10: Агент рухається до (0, 1)
# 🔍 Сканування сусідніх перехресть для вузла (0, 1): [(0, 0), (1, 1)]
# TELL: Дорога (0, 1) <-> (0, 0) додана в базу знань.
# TELL: Дорожній знак (0, 1) -> (0, 0): up додано.
# 🚸 Дорожній знак: з (0, 1) у (0, 0) -> up
# TELL: Дорога (0, 1) <-> (1, 1) додана в базу знань.
# TELL: Дорожній знак (0, 1) -> (1, 1): right додано.
# 🚸 Дорожній знак: з (0, 1) у (1, 1) -> right
# 👀 Додано до бачених вузлів: (1, 1)
# 🧭 Поточний напрямок: down
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (1, 1)
# TELL: Вузол (1, 1) додано до відвіданих.
#
# 🚗 Крок 11: Агент рухається до (1, 1)
# 🔍 Сканування сусідніх перехресть для вузла (1, 1): [(1, 2), (0, 1)]
# TELL: Дорога (1, 1) <-> (1, 2) додана в базу знань.
# TELL: Дорожній знак (1, 1) -> (1, 2): down додано.
# 🚸 Дорожній знак: з (1, 1) у (1, 2) -> down
# 👀 Додано до бачених вузлів: (1, 2)
# TELL: Дорога (1, 1) <-> (0, 1) додана в базу знань.
# TELL: Дорожній знак (1, 1) -> (0, 1): left додано.
# 🚸 Дорожній знак: з (1, 1) у (0, 1) -> left
# 🧭 Поточний напрямок: right
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (1, 2)
# TELL: Вузол (1, 2) додано до відвіданих.
#
# 🚗 Крок 12: Агент рухається до (1, 2)
# 🔍 Сканування сусідніх перехресть для вузла (1, 2): [(2, 2), (1, 1), (1, 3)]
# TELL: Дорога (1, 2) <-> (2, 2) додана в базу знань.
# TELL: Дорожній знак (1, 2) -> (2, 2): right додано.
# 🚸 Дорожній знак: з (1, 2) у (2, 2) -> right
# 👀 Додано до бачених вузлів: (2, 2)
# TELL: Дорога (1, 2) <-> (1, 1) додана в базу знань.
# TELL: Дорожній знак (1, 2) -> (1, 1): up додано.
# 🚸 Дорожній знак: з (1, 2) у (1, 1) -> up
# TELL: Дорога (1, 2) <-> (1, 3) додана в базу знань.
# TELL: Дорожній знак (1, 2) -> (1, 3): down додано.
# 🚸 Дорожній знак: з (1, 2) у (1, 3) -> down
# 👀 Додано до бачених вузлів: (1, 3)
# 🧭 Поточний напрямок: down
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (1, 3)
# TELL: Вузол (1, 3) додано до відвіданих.
#
# 🚗 Крок 13: Агент рухається до (1, 3)
# 🔍 Сканування сусідніх перехресть для вузла (1, 3): [(0, 3), (2, 3), (1, 2), (1, 4)]
# TELL: Дорога (1, 3) <-> (0, 3) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (0, 3): left додано.
# 🚸 Дорожній знак: з (1, 3) у (0, 3) -> left
# 👀 Додано до бачених вузлів: (0, 3)
# TELL: Дорога (1, 3) <-> (2, 3) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (2, 3): right додано.
# 🚸 Дорожній знак: з (1, 3) у (2, 3) -> right
# 👀 Додано до бачених вузлів: (2, 3)
# TELL: Дорога (1, 3) <-> (1, 2) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (1, 2): up додано.
# 🚸 Дорожній знак: з (1, 3) у (1, 2) -> up
# TELL: Дорога (1, 3) <-> (1, 4) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (1, 4): down додано.
# 🚸 Дорожній знак: з (1, 3) у (1, 4) -> down
# ⚠ Виявлено тупиковий вузол: (1, 4), він буде уникатись.
# 👀 Додано до бачених вузлів: (1, 4)
# 🧭 Поточний напрямок: down
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (2, 3)
# TELL: Вузол (2, 3) додано до відвіданих.
#
# 🚗 Крок 14: Агент рухається до (2, 3)
# 🔍 Сканування сусідніх перехресть для вузла (2, 3): [(1, 3), (2, 4)]
# TELL: Дорога (2, 3) <-> (1, 3) додана в базу знань.
# TELL: Дорожній знак (2, 3) -> (1, 3): left додано.
# 🚸 Дорожній знак: з (2, 3) у (1, 3) -> left
# TELL: Дорога (2, 3) <-> (2, 4) додана в базу знань.
# TELL: Дорожній знак (2, 3) -> (2, 4): down додано.
# 🚸 Дорожній знак: з (2, 3) у (2, 4) -> down
# ⚠ Виявлено тупиковий вузол: (2, 4), він буде уникатись.
# 👀 Додано до бачених вузлів: (2, 4)
# 🧭 Поточний напрямок: right
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (0, 3)
# TELL: Вузол (1, 3) додано до відвіданих.
#
# 🚗 Крок 15: Агент рухається до (1, 3)
# 🔍 Сканування сусідніх перехресть для вузла (1, 3): [(0, 3), (2, 3), (1, 2), (1, 4)]
# TELL: Дорога (1, 3) <-> (0, 3) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (0, 3): left додано.
# 🚸 Дорожній знак: з (1, 3) у (0, 3) -> left
# TELL: Дорога (1, 3) <-> (2, 3) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (2, 3): right додано.
# 🚸 Дорожній знак: з (1, 3) у (2, 3) -> right
# TELL: Дорога (1, 3) <-> (1, 2) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (1, 2): up додано.
# 🚸 Дорожній знак: з (1, 3) у (1, 2) -> up
# TELL: Дорога (1, 3) <-> (1, 4) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (1, 4): down додано.
# 🚸 Дорожній знак: з (1, 3) у (1, 4) -> down
# ⚠ Виявлено тупиковий вузол: (1, 4), він буде уникатись.
# 🧭 Поточний напрямок: left
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (0, 3)
# TELL: Вузол (0, 3) додано до відвіданих.
#
# 🚗 Крок 16: Агент рухається до (0, 3)
# 🔍 Сканування сусідніх перехресть для вузла (0, 3): [(1, 3), (0, 2), (0, 4)]
# TELL: Дорога (0, 3) <-> (1, 3) додана в базу знань.
# TELL: Дорожній знак (0, 3) -> (1, 3): right додано.
# 🚸 Дорожній знак: з (0, 3) у (1, 3) -> right
# TELL: Дорога (0, 3) <-> (0, 2) додана в базу знань.
# TELL: Дорожній знак (0, 3) -> (0, 2): up додано.
# 🚸 Дорожній знак: з (0, 3) у (0, 2) -> up
# ⚠ Виявлено тупиковий вузол: (0, 2), він буде уникатись.
# 👀 Додано до бачених вузлів: (0, 2)
# TELL: Дорога (0, 3) <-> (0, 4) додана в базу знань.
# TELL: Дорожній знак (0, 3) -> (0, 4): down додано.
# 🚸 Дорожній знак: з (0, 3) у (0, 4) -> down
# ⚠ Виявлено тупиковий вузол: (0, 4), він буде уникатись.
# 👀 Додано до бачених вузлів: (0, 4)
# 🧭 Поточний напрямок: left
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (2, 2)
# TELL: Вузол (1, 3) додано до відвіданих.
#
# 🚗 Крок 17: Агент рухається до (1, 3)
# 🔍 Сканування сусідніх перехресть для вузла (1, 3): [(0, 3), (2, 3), (1, 2), (1, 4)]
# TELL: Дорога (1, 3) <-> (0, 3) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (0, 3): left додано.
# 🚸 Дорожній знак: з (1, 3) у (0, 3) -> left
# TELL: Дорога (1, 3) <-> (2, 3) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (2, 3): right додано.
# 🚸 Дорожній знак: з (1, 3) у (2, 3) -> right
# TELL: Дорога (1, 3) <-> (1, 2) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (1, 2): up додано.
# 🚸 Дорожній знак: з (1, 3) у (1, 2) -> up
# TELL: Дорога (1, 3) <-> (1, 4) додана в базу знань.
# TELL: Дорожній знак (1, 3) -> (1, 4): down додано.
# 🚸 Дорожній знак: з (1, 3) у (1, 4) -> down
# ⚠ Виявлено тупиковий вузол: (1, 4), він буде уникатись.
# 🧭 Поточний напрямок: right
# 🔄 ЦИКЛ ВИЯВЛЕНО! ВХІД У СТАН ТУПИКА на вузлі (1, 3)
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (2, 2)
# TELL: Вузол (1, 2) додано до відвіданих.
#
# 🚗 Крок 18: Агент рухається до (1, 2)
# 🔍 Сканування сусідніх перехресть для вузла (1, 2): [(2, 2), (1, 1), (1, 3)]
# TELL: Дорога (1, 2) <-> (2, 2) додана в базу знань.
# TELL: Дорожній знак (1, 2) -> (2, 2): right додано.
# 🚸 Дорожній знак: з (1, 2) у (2, 2) -> right
# TELL: Дорога (1, 2) <-> (1, 1) додана в базу знань.
# TELL: Дорожній знак (1, 2) -> (1, 1): up додано.
# 🚸 Дорожній знак: з (1, 2) у (1, 1) -> up
# TELL: Дорога (1, 2) <-> (1, 3) додана в базу знань.
# TELL: Дорожній знак (1, 2) -> (1, 3): down додано.
# 🚸 Дорожній знак: з (1, 2) у (1, 3) -> down
# 🧭 Поточний напрямок: up
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (2, 2)
# TELL: Вузол (2, 2) додано до відвіданих.
#
# 🚗 Крок 19: Агент рухається до (2, 2)
# 🔍 Сканування сусідніх перехресть для вузла (2, 2): [(1, 2), (3, 2)]
# TELL: Дорога (2, 2) <-> (1, 2) додана в базу знань.
# TELL: Дорожній знак (2, 2) -> (1, 2): left додано.
# 🚸 Дорожній знак: з (2, 2) у (1, 2) -> left
# TELL: Дорога (2, 2) <-> (3, 2) додана в базу знань.
# TELL: Дорожній знак (2, 2) -> (3, 2): right додано.
# 🚸 Дорожній знак: з (2, 2) у (3, 2) -> right
# 👀 Додано до бачених вузлів: (3, 2)
# 🧭 Поточний напрямок: right
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (3, 2)
# TELL: Вузол (3, 2) додано до відвіданих.
#
# 🚗 Крок 20: Агент рухається до (3, 2)
# 🔍 Сканування сусідніх перехресть для вузла (3, 2): [(2, 2), (3, 3), (3, 1)]
# TELL: Дорога (3, 2) <-> (2, 2) додана в базу знань.
# TELL: Дорожній знак (3, 2) -> (2, 2): left додано.
# 🚸 Дорожній знак: з (3, 2) у (2, 2) -> left
# TELL: Дорога (3, 2) <-> (3, 3) додана в базу знань.
# TELL: Дорожній знак (3, 2) -> (3, 3): down додано.
# 🚸 Дорожній знак: з (3, 2) у (3, 3) -> down
# 👀 Додано до бачених вузлів: (3, 3)
# TELL: Дорога (3, 2) <-> (3, 1) додана в базу знань.
# TELL: Дорожній знак (3, 2) -> (3, 1): up додано.
# 🚸 Дорожній знак: з (3, 2) у (3, 1) -> up
# ⚠ Виявлено тупиковий вузол: (3, 1), він буде уникатись.
# 👀 Додано до бачених вузлів: (3, 1)
# 🧭 Поточний напрямок: right
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (3, 3)
# TELL: Вузол (3, 3) додано до відвіданих.
#
# 🚗 Крок 21: Агент рухається до (3, 3)
# 🔍 Сканування сусідніх перехресть для вузла (3, 3): [(3, 2), (4, 3), (3, 4)]
# TELL: Дорога (3, 3) <-> (3, 2) додана в базу знань.
# TELL: Дорожній знак (3, 3) -> (3, 2): up додано.
# 🚸 Дорожній знак: з (3, 3) у (3, 2) -> up
# TELL: Дорога (3, 3) <-> (4, 3) додана в базу знань.
# TELL: Дорожній знак (3, 3) -> (4, 3): right додано.
# 🚸 Дорожній знак: з (3, 3) у (4, 3) -> right
# 👀 Додано до бачених вузлів: (4, 3)
# TELL: Дорога (3, 3) <-> (3, 4) додана в базу знань.
# TELL: Дорожній знак (3, 3) -> (3, 4): down додано.
# 🚸 Дорожній знак: з (3, 3) у (3, 4) -> down
# ⚠ Виявлено тупиковий вузол: (3, 4), він буде уникатись.
# 👀 Додано до бачених вузлів: (3, 4)
# 🧭 Поточний напрямок: down
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (4, 3)
# TELL: Вузол (4, 3) додано до відвіданих.
#
# 🚗 Крок 22: Агент рухається до (4, 3)
# 🔍 Сканування сусідніх перехресть для вузла (4, 3): [(4, 4), (3, 3), (4, 2)]
# TELL: Дорога (4, 3) <-> (4, 4) додана в базу знань.
# TELL: Дорожній знак (4, 3) -> (4, 4): down додано.
# 🚸 Дорожній знак: з (4, 3) у (4, 4) -> down
# 👀 Додано до бачених вузлів: (4, 4)
# TELL: Дорога (4, 3) <-> (3, 3) додана в базу знань.
# TELL: Дорожній знак (4, 3) -> (3, 3): left додано.
# 🚸 Дорожній знак: з (4, 3) у (3, 3) -> left
# TELL: Дорога (4, 3) <-> (4, 2) додана в базу знань.
# TELL: Дорожній знак (4, 3) -> (4, 2): up додано.
# 🚸 Дорожній знак: з (4, 3) у (4, 2) -> up
# 👀 Додано до бачених вузлів: (4, 2)
# 🧭 Поточний напрямок: right
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (4, 2)
# TELL: Вузол (4, 2) додано до відвіданих.
#
# 🚗 Крок 23: Агент рухається до (4, 2)
# 🔍 Сканування сусідніх перехресть для вузла (4, 2): [(4, 1), (4, 3)]
# TELL: Дорога (4, 2) <-> (4, 1) додана в базу знань.
# TELL: Дорожній знак (4, 2) -> (4, 1): up додано.
# 🚸 Дорожній знак: з (4, 2) у (4, 1) -> up
# ⚠ Виявлено тупиковий вузол: (4, 1), він буде уникатись.
# 👀 Додано до бачених вузлів: (4, 1)
# TELL: Дорога (4, 2) <-> (4, 3) додана в базу знань.
# TELL: Дорожній знак (4, 2) -> (4, 3): down додано.
# 🚸 Дорожній знак: з (4, 2) у (4, 3) -> down
# 🧭 Поточний напрямок: up
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (4, 4)
# TELL: Вузол (4, 3) додано до відвіданих.
#
# 🚗 Крок 24: Агент рухається до (4, 3)
# 🔍 Сканування сусідніх перехресть для вузла (4, 3): [(4, 4), (3, 3), (4, 2)]
# TELL: Дорога (4, 3) <-> (4, 4) додана в базу знань.
# TELL: Дорожній знак (4, 3) -> (4, 4): down додано.
# 🚸 Дорожній знак: з (4, 3) у (4, 4) -> down
# TELL: Дорога (4, 3) <-> (3, 3) додана в базу знань.
# TELL: Дорожній знак (4, 3) -> (3, 3): left додано.
# 🚸 Дорожній знак: з (4, 3) у (3, 3) -> left
# TELL: Дорога (4, 3) <-> (4, 2) додана в базу знань.
# TELL: Дорожній знак (4, 3) -> (4, 2): up додано.
# 🚸 Дорожній знак: з (4, 3) у (4, 2) -> up
# 🧭 Поточний напрямок: down
# ↩ ТУПИК! Агент прямує покроково до жовтої точки (4, 4)
# TELL: Вузол (4, 4) додано до відвіданих.
# 🏁 Досягнуто кінцевої точки! Додана (4, 4) до visited_nodes.
# ✅ Рух завершено!
# 📊 Фактична кількість кроків агента: 24
# Шлях агента: [(0, 0), (1, 0), (2, 0), (3, 0), (2, 0), (3, 0), (2, 0), (1, 0), (0, 0), (0, 1), (1, 1), (1, 2), (1, 3), (2, 3), (1, 3), (0, 3), (1, 3), (1, 2), (2, 2), (3, 2), (3, 3), (4, 3), (4, 2), (4, 3), (4, 4)]
# Фінальна позиція: (4, 4)
# ✅ Усі тести пройдені успішно!
